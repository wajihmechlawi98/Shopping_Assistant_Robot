# %% [markdown]
# <a href="https://colab.research.google.com/github/misbah4064/age_and_gender_detection/blob/master/age%26genderDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/misbah4064/age_and_gender_detection.git
# %cd age_and_gender_detection
# Out:
# Cloning into 'age_and_gender_detection'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# /content/age_and_gender_detection

# %%
# Downloading pretrained data and unzipping it
# !gdown https://drive.google.com/uc?id=1_aDScOvBeBLCn_iv0oxSO8X1ySQpSbIS
# https://drive.google.com/uc?id=1_aDScOvBeBLCn_iv0oxSO8X1ySQpSbIS
# !unzip modelNweight.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_aDScOvBeBLCn_iv0oxSO8X1ySQpSbIS
# To: /content/age_and_gender_detection/modelNweight.zip
# 86.2MB [00:00, 237MB/s]
# Archive:  modelNweight.zip
#    creating: modelNweight/
#   inflating: modelNweight/age_deploy.prototxt
#   inflating: modelNweight/age_net.caffemodel
#   inflating: modelNweight/gender_deploy.prototxt
#   inflating: modelNweight/gender_net.caffemodel
#   inflating: modelNweight/opencv_face_detector.pbtxt
#   inflating: modelNweight/opencv_face_detector_uint8.pb

# %%
# Import required modules
import cv2 as cv
import math
import time
# import argparse

def getFaceBox(net, frame, conf_threshold=0.7):
    frameOpencvDnn = frame.copy()
    frameHeight = frameOpencvDnn.shape[0]
    frameWidth = frameOpencvDnn.shape[1]
    blob = cv.dnn.blobFromImage(frameOpencvDnn, 1.0, (300, 300), [104, 117, 123], True, False)

    net.setInput(blob)
    detections = net.forward()
    bboxes = []
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > conf_threshold:
            x1 = int(detections[0, 0, i, 3] * frameWidth)
            y1 = int(detections[0, 0, i, 4] * frameHeight)
            x2 = int(detections[0, 0, i, 5] * frameWidth)
            y2 = int(detections[0, 0, i, 6] * frameHeight)
            bboxes.append([x1, y1, x2, y2])
            cv.rectangle(frameOpencvDnn, (x1, y1), (x2, y2), (0, 255, 0), int(round(frameHeight/150)), 8)
    return frameOpencvDnn, bboxes

faceProto = "modelNweight/opencv_face_detector.pbtxt"
faceModel = "modelNweight/opencv_face_detector_uint8.pb"

ageProto = "modelNweight/age_deploy.prototxt"
ageModel = "modelNweight/age_net.caffemodel"

genderProto = "modelNweight/gender_deploy.prototxt"
genderModel = "modelNweight/gender_net.caffemodel"

MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
ageList = ['(0-2)', '(4-6)', '(8-12)', '(15-20)', '(25-32)', '(38-43)', '(48-53)', '(60-100)']
genderList = ['Male', 'Female']

# Load network
ageNet = cv.dnn.readNet(ageModel, ageProto)
genderNet = cv.dnn.readNet(genderModel, genderProto)
faceNet = cv.dnn.readNet(faceModel, faceProto)

padding = 20

def age_gender_detector(frame):
    # Read frame
    t = time.time()
    frameFace, bboxes = getFaceBox(faceNet, frame)
    for bbox in bboxes:
        # print(bbox)
        face = frame[max(0,bbox[1]-padding):min(bbox[3]+padding,frame.shape[0]-1),max(0,bbox[0]-padding):min(bbox[2]+padding, frame.shape[1]-1)]

        blob = cv.dnn.blobFromImage(face, 1.0, (227, 227), MODEL_MEAN_VALUES, swapRB=False)
        genderNet.setInput(blob)
        genderPreds = genderNet.forward()
        gender = genderList[genderPreds[0].argmax()]
        # print("Gender Output : {}".format(genderPreds))
        print("Gender : {}, conf = {:.3f}".format(gender, genderPreds[0].max()))

        ageNet.setInput(blob)
        agePreds = ageNet.forward()
        age = ageList[agePreds[0].argmax()]
        print("Age Output : {}".format(agePreds))
        print("Age : {}, conf = {:.3f}".format(age, agePreds[0].max()))

        label = "{},{}".format(gender, age)
        cv.putText(frameFace, label, (bbox[0], bbox[1]-10), cv.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2, cv.LINE_AA)
    return frameFace

# %%
input = cv.imread("image.jpg")
output = age_gender_detector(input)
cv.imshow("output", output)
cv.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 input = cv.imread("image.jpg")
#       2 output = age_gender_detector(input)
#       3 cv.imshow("output", output)
#
# NameError: name 'cv' is not defined

# %%
input = cv.imread("image1.jpg")
output = age_gender_detector(input)
cv.imshow(output)
# Out:
# Gender : Male, conf = 1.000
# Age Output : [[7.0540545e-07 3.7358481e-05 2.0373721e-02 1.6500570e-03 9.7762191e-01
#   3.0096623e-04 6.1850023e-06 9.2617875e-06]]
# Age : (25-32), conf = 0.978
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 3
#       1 input = cv.imread("image1.jpg")
#       2 output = age_gender_detector(input)
# ----> 3 cv.imshow(output)
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)

# %%
input = cv.imread("image2.jpg")
output = age_gender_detector(input)
cv2_imshow(output)
# Out:
# Gender : Male, conf = 1.000
# Age Output : [[1.9950876e-03 5.0318660e-05 8.4574794e-04 1.4283879e-04 7.5796200e-04
#   1.0425225e-01 4.2547666e-02 8.4940809e-01]]
# Age : (60-100), conf = 0.849
# <PIL.Image.Image image mode=RGB size=600x338 at 0x7FF19A542FD0>

# %%
import cv2
cap = cv2.VideoCapture('video.mp4')
ret, frame = cap.read()
frame_height, frame_width, _ = frame.shape
out = cv2.VideoWriter('output.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 10, (frame_width,frame_height))
print("Processing Video...")
while cap.isOpened():
  ret, frame = cap.read()
  if not ret:
    out.release()
    break
  output = age_gender_detector(frame)
  out.write(output)
out.release()
print("Done processing video")
# Out:
# Processing Video...
# Gender : Male, conf = 0.991
# Age Output : [[1.9485973e-04 9.9193573e-01 7.8223916e-03 1.4352014e-05 9.5806008e-06
#   1.9119801e-05 2.5295024e-06 1.5240112e-06]]
# Age : (4-6), conf = 0.992
# Gender : Female, conf = 0.965
# Age Output : [[9.54717159e-01 3.23594920e-02 1.22785373e-02 1.11674795e-04
#   2.20690446e-04 1.97814603e-04 4.04391576e-05 7.43513447e-05]]
# Age : (0-2), conf = 0.955
# Gender : Male, conf = 0.979
# Age Output : [[4.58503026e-04 9.81036663e-01 1.80823803e-02 1.30004919e-04
#   1.00299607e-04 1.55990580e-04 2.52459122e-05 1.07117985e-05]]
# Age : (4-6), conf = 0.981
# Gender : Female, conf = 0.977
# Age Output : [[8.9754087e-01 4.6496905e-02 5.3314965e-02 3.3239796e-04 1.1227333e-03
#   8.3362858e-04 1.3022518e-04 2.2832594e-04]]
# Age : (0-2), conf = 0.898
# Gender : Male, conf = 0.996
# Age Output : [[7.5695402e-04 9.7670263e-01 2.1732567e-02 2.4847430e-04 1.6005455e-04
#   3.1052224e-04 6.4130130e-05 2.4523602e-05]]
# Age : (4-6), conf = 0.977
# Gender : Female, conf = 0.978
# Age Output : [[9.2562163e-01 3.6080223e-02 3.6696527e-02 1.8871728e-04 6.2966364e-04
#   5.3562736e-04 9.8190016e-05 1.4951351e-04]]
# Age : (0-2), conf = 0.926
# Gender : Male, conf = 0.998
# Age Output : [[8.6366344e-04 9.7562569e-01 2.2607502e-02 3.1292447e-04 1.5987077e-04
#   3.2731626e-04 7.4458141e-05 2.8605094e-05]]
# Age : (4-6), conf = 0.976
# Gender : Female, conf = 0.948
# Age Output : [[9.69385922e-01 1.83642674e-02 1.11728525e-02 1.08501088e-04
#   4.56766575e-04 3.35477293e-04 7.19673189e-05 1.04091690e-04]]
# Age : (0-2), conf = 0.969
# Gender : Male, conf = 0.998
# Age Output : [[9.3156187e-04 9.7766441e-01 2.0458804e-02 3.1901611e-04 1.9168561e-04
#   3.2478507e-04 7.9729100e-05 2.9969335e-05]]
# Age : (4-6), conf = 0.978
# Gender : Male, conf = 0.711
# Age Output : [[9.8563218e-01 7.6071676e-03 6.0388921e-03 5.6194996e-05 3.1680317e-04
#   2.4424749e-04 3.8460661e-05 6.6162756e-05]]
# Age : (0-2), conf = 0.986
# Gender : Male, conf = 0.997
# Age Output : [[6.8357086e-04 9.7967964e-01 1.8990120e-02 2.0554631e-04 1.3435035e-04
#   2.2973091e-04 5.5813693e-05 2.1277159e-05]]
# Age : (4-6), conf = 0.980
# Gender : Female, conf = 0.522
# Age Output : [[9.9416417e-01 3.9863070e-03 1.5363784e-03 2.1889409e-05 1.3326890e-04
#   1.1377105e-04 1.4258667e-05 2.9861434e-05]]
# Age : (0-2), conf = 0.994
# Gender : Female, conf = 0.925
# Age Output : [[9.95462120e-01 3.53382505e-03 7.90257414e-04 1.38622254e-05
#   1.10470006e-04 6.34163080e-05 9.64589162e-06 1.64626017e-05]]
# Age : (0-2), conf = 0.995
# Gender : Male, conf = 0.995
# Age Output : [[8.8327710e-04 9.8055273e-01 1.7608402e-02 2.8045368e-04 2.1840757e-04
#   3.3963736e-04 8.7232962e-05 2.9940875e-05]]
# Age : (4-6), conf = 0.981
# Gender : Female, conf = 0.815
# Age Output : [[9.9753273e-01 2.0743061e-03 2.5567622e-04 7.3087199e-06 7.7200835e-05
#   3.5901689e-05 5.9970807e-06 1.0886000e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.995
# Age Output : [[1.0595586e-03 9.8094016e-01 1.6931966e-02 2.9341195e-04 2.6574044e-04
#   3.8223361e-04 9.3466530e-05 3.3429089e-05]]
# Age : (4-6), conf = 0.981
# Gender : Female, conf = 0.976
# Age Output : [[9.9433100e-01 4.2553199e-03 9.3948218e-04 2.8783346e-05 2.6218893e-04
#   1.3102205e-04 2.1553806e-05 3.0541265e-05]]
# Age : (0-2), conf = 0.994
# Gender : Male, conf = 0.997
# Age Output : [[1.7492329e-03 9.8013777e-01 1.6569659e-02 4.1507831e-04 4.0209483e-04
#   5.4023886e-04 1.3873279e-04 4.7284499e-05]]
# Age : (4-6), conf = 0.980
# Gender : Female, conf = 0.917
# Age Output : [[9.9436235e-01 4.3482496e-03 7.2467671e-04 3.5184530e-05 3.0572806e-04
#   1.6066706e-04 2.5154841e-05 3.8091694e-05]]
# Age : (0-2), conf = 0.994
# Gender : Male, conf = 0.999
# Age Output : [[1.7633416e-03 9.8128569e-01 1.4990747e-02 4.8892054e-04 5.3438789e-04
#   6.8609597e-04 1.9311732e-04 5.7675679e-05]]
# Age : (4-6), conf = 0.981
# Gender : Female, conf = 0.978
# Age Output : [[9.9756455e-01 1.9811434e-03 2.6156945e-04 8.6054179e-06 1.1677423e-04
#   4.4956210e-05 8.2279039e-06 1.4153616e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.999
# Age Output : [[1.6351952e-03 9.7506678e-01 2.0803053e-02 7.5605256e-04 4.2679996e-04
#   1.0180053e-03 2.2714725e-04 6.7003646e-05]]
# Age : (4-6), conf = 0.975
# Gender : Male, conf = 0.999
# Age Output : [[1.6439261e-03 9.8068339e-01 1.5961180e-02 5.7042605e-04 2.7245554e-04
#   6.7974668e-04 1.4118687e-04 4.7665886e-05]]
# Age : (4-6), conf = 0.981
# Gender : Female, conf = 0.709
# Age Output : [[9.9905390e-01 8.4324670e-04 6.4389831e-05 1.4021501e-06 2.4487377e-05
#   7.6087654e-06 1.4914641e-06 3.3541280e-06]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.999
# Age Output : [[1.2554374e-03 9.8506749e-01 1.2440526e-02 3.4279338e-04 2.2071761e-04
#   5.2390510e-04 1.1517245e-04 3.3890519e-05]]
# Age : (4-6), conf = 0.985
# Gender : Female, conf = 0.987
# Age Output : [[9.9774688e-01 1.9542184e-03 1.8252649e-04 4.9580035e-06 7.5894583e-05
#   2.2003798e-05 4.5324236e-06 8.9047871e-06]]
# Age : (0-2), conf = 0.998
# Gender : Female, conf = 0.987
# Age Output : [[9.9780291e-01 1.7206630e-03 2.6926550e-04 6.6015382e-06 1.3212312e-04
#   4.5060809e-05 8.6091586e-06 1.4720747e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.999
# Age Output : [[6.5229501e-04 9.8896259e-01 9.7639784e-03 9.8988166e-05 1.5636305e-04
#   2.7156755e-04 7.9026438e-05 1.5360589e-05]]
# Age : (4-6), conf = 0.989
# Gender : Female, conf = 0.992
# Age Output : [[9.9771285e-01 1.7996954e-03 2.8719704e-04 7.1933841e-06 1.2284688e-04
#   4.5959121e-05 8.8273682e-06 1.5476362e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.999
# Age Output : [[3.7788253e-04 9.9218506e-01 7.0745014e-03 7.6174067e-05 8.1947554e-05
#   1.6107890e-04 3.4295415e-05 8.9598279e-06]]
# Age : (4-6), conf = 0.992
# Gender : Male, conf = 0.994
# Age Output : [[1.29318636e-04 9.90464807e-01 9.16694850e-03 8.50179858e-05
#   4.27869090e-05 9.06706700e-05 1.49430625e-05 5.53124528e-06]]
# Age : (4-6), conf = 0.990
# Gender : Female, conf = 0.994
# Age Output : [[9.9806780e-01 1.6054682e-03 2.0902911e-04 4.6209443e-06 6.7615510e-05
#   2.7916107e-05 5.8981918e-06 1.1554360e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.956
# Age Output : [[8.3499275e-05 9.9266750e-01 7.0595983e-03 7.3113719e-05 3.8164791e-05
#   6.3815431e-05 1.0339670e-05 3.8713538e-06]]
# Age : (4-6), conf = 0.993
# Gender : Female, conf = 0.991
# Age Output : [[9.9798989e-01 1.6439607e-03 2.3457812e-04 6.7899618e-06 5.5540408e-05
#   3.8559105e-05 8.7162134e-06 2.2060955e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.995
# Age Output : [[1.32277273e-04 9.90701437e-01 8.93738028e-03 3.62793326e-05
#   6.13495577e-05 1.09031804e-04 1.70596250e-05 5.33322600e-06]]
# Age : (4-6), conf = 0.991
# Gender : Female, conf = 0.995
# Age Output : [[9.9489611e-01 3.5395406e-03 9.6495618e-04 3.2667169e-05 2.3642930e-04
#   2.0116808e-04 4.0992145e-05 8.8231864e-05]]
# Age : (0-2), conf = 0.995
# Gender : Female, conf = 0.999
# Age Output : [[9.9192530e-01 5.1184790e-03 1.7157921e-03 4.0054627e-05 7.3648430e-04
#   2.8390696e-04 8.2166371e-05 9.7909709e-05]]
# Age : (0-2), conf = 0.992
# Gender : Male, conf = 0.950
# Age Output : [[1.8801304e-04 9.8845482e-01 1.0956808e-02 9.6187709e-05 8.8813984e-05
#   1.7557501e-04 3.0365511e-05 9.3650633e-06]]
# Age : (4-6), conf = 0.988
# Gender : Female, conf = 0.999
# Age Output : [[9.9127918e-01 6.7175026e-03 1.4251416e-03 2.7299642e-05 3.2283281e-04
#   1.3642108e-04 3.7700262e-05 5.4027281e-05]]
# Age : (0-2), conf = 0.991
# Gender : Male, conf = 0.946
# Age Output : [[1.1682547e-04 9.8925996e-01 1.0310291e-02 1.1583969e-04 6.4662119e-05
#   1.0609283e-04 1.9534800e-05 6.7098304e-06]]
# Age : (4-6), conf = 0.989
# Gender : Female, conf = 0.999
# Age Output : [[9.9638462e-01 2.5882362e-03 6.6509203e-04 1.6519816e-05 1.4073080e-04
#   1.1433438e-04 2.6494137e-05 6.4051477e-05]]
# Age : (0-2), conf = 0.996
# Gender : Male, conf = 0.955
# Age Output : [[1.3276000e-04 9.8319191e-01 1.6301965e-02 1.5752709e-04 7.4695941e-05
#   1.1132375e-04 2.1584892e-05 8.2205415e-06]]
# Age : (4-6), conf = 0.983
# Gender : Female, conf = 0.999
# Age Output : [[9.9574810e-01 2.6716436e-03 9.6216949e-04 2.6681020e-05 2.1494066e-04
#   1.9491449e-04 5.3419353e-05 1.2807427e-04]]
# Age : (0-2), conf = 0.996
# Gender : Male, conf = 0.999
# Age Output : [[3.1289371e-04 9.7793090e-01 2.1633629e-02 9.1099164e-06 4.7821351e-05
#   5.5678236e-05 6.6718362e-06 3.4210334e-06]]
# Age : (4-6), conf = 0.978
# Gender : Female, conf = 0.999
# Age Output : [[9.9904484e-01 7.7200390e-04 1.2367750e-04 2.4162996e-06 2.0727059e-05
#   1.5305706e-05 3.3900076e-06 1.7707500e-05]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.999
# Age Output : [[3.1426697e-04 9.1599739e-01 8.3014980e-02 3.9745410e-05 2.2824209e-04
#   3.4864494e-04 4.1282277e-05 1.5455164e-05]]
# Age : (4-6), conf = 0.916
# Gender : Female, conf = 0.999
# Age Output : [[9.9871802e-01 1.0269290e-03 1.6608820e-04 3.8698458e-06 3.3996817e-05
#   2.2407035e-05 5.3695053e-06 2.3159831e-05]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.999
# Age Output : [[7.5849349e-04 8.6130279e-01 1.3649414e-01 1.0281220e-04 5.4168189e-04
#   6.5646798e-04 8.3686617e-05 5.9900151e-05]]
# Age : (4-6), conf = 0.861
# Gender : Female, conf = 1.000
# Age Output : [[9.9813432e-01 1.3345624e-03 3.2902477e-04 7.5072699e-06 7.4882671e-05
#   5.4634540e-05 1.2778505e-05 5.2503940e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.998
# Age Output : [[1.1855911e-03 6.3607681e-01 3.5260072e-01 1.0709636e-03 4.7514359e-03
#   2.9004698e-03 1.0978209e-03 3.1609510e-04]]
# Age : (4-6), conf = 0.636
# Gender : Female, conf = 0.999
# Age Output : [[9.9817765e-01 1.4101573e-03 2.4449881e-04 6.1693045e-06 9.0032117e-05
#   3.7471407e-05 9.2796126e-06 2.4612655e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.861
# Age Output : [[2.8588984e-04 7.5248671e-01 2.4001850e-01 2.0873789e-03 2.5980794e-03
#   1.9383171e-03 4.5216270e-04 1.3296305e-04]]
# Age : (4-6), conf = 0.752
# Gender : Female, conf = 0.999
# Age Output : [[9.9879754e-01 9.6515176e-04 1.5023811e-04 3.0755127e-06 4.5251614e-05
#   1.9703124e-05 4.5679708e-06 1.4508169e-05]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.919
# Age Output : [[4.2727755e-04 6.6854137e-01 3.1492159e-01 4.9716546e-03 5.2485769e-03
#   4.5467643e-03 1.0690613e-03 2.7374923e-04]]
# Age : (4-6), conf = 0.669
# Gender : Female, conf = 0.998
# Age Output : [[9.9862254e-01 1.1172375e-03 1.5230235e-04 3.4927664e-06 6.5743116e-05
#   1.9870082e-05 5.2018254e-06 1.3688786e-05]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.995
# Age Output : [[0.00230471 0.21064714 0.6753389  0.00713638 0.06794621 0.02549037
#   0.00903321 0.00210316]]
# Age : (8-12), conf = 0.675
# Gender : Female, conf = 0.999
# Age Output : [[9.9747449e-01 2.0714994e-03 2.5836600e-04 6.6032053e-06 1.2523786e-04
#   3.3060773e-05 1.0575988e-05 2.0128628e-05]]
# Age : (0-2), conf = 0.997
# Gender : Male, conf = 0.995
# Age Output : [[0.00448035 0.24852984 0.55537605 0.01600548 0.09337822 0.05927462
#   0.01817698 0.00477841]]
# Age : (8-12), conf = 0.555
# Gender : Female, conf = 0.999
# Age Output : [[9.9411619e-01 4.4373614e-03 7.1709161e-04 1.8300774e-05 5.7714875e-04
#   7.6956414e-05 2.6515056e-05 3.0508518e-05]]
# Age : (0-2), conf = 0.994
# Gender : Male, conf = 0.994
# Age Output : [[0.00272629 0.23390748 0.6046325  0.01363493 0.08060092 0.04150311
#   0.01831118 0.00468362]]
# Age : (8-12), conf = 0.605
# Gender : Female, conf = 0.999
# Age Output : [[9.9799275e-01 1.7040787e-03 1.5849916e-04 3.6906179e-06 1.0680392e-04
#   1.7583465e-05 6.4513656e-06 1.0146403e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.978
# Age Output : [[0.00246833 0.5880743  0.33526832 0.01778143 0.02494757 0.0220699
#   0.00726963 0.00212034]]
# Age : (4-6), conf = 0.588
# Gender : Female, conf = 0.999
# Age Output : [[9.9641341e-01 2.4640930e-03 4.8041242e-04 1.2604938e-05 4.3593813e-04
#   9.7337070e-05 4.1616000e-05 5.4787972e-05]]
# Age : (0-2), conf = 0.996
# Gender : Female, conf = 0.503
# Age Output : [[0.00181372 0.7366609  0.18656848 0.03243347 0.0144759  0.02114408
#   0.00500372 0.00189977]]
# Age : (4-6), conf = 0.737
# Gender : Female, conf = 0.999
# Age Output : [[9.95737433e-01 2.88420473e-03 7.61509407e-04 1.82152271e-05
#   3.80933925e-04 1.17097625e-04 3.78525474e-05 6.28990092e-05]]
# Age : (0-2), conf = 0.996
# Gender : Female, conf = 0.794
# Age Output : [[0.00192212 0.73325133 0.18512127 0.03385903 0.01813425 0.02032928
#   0.00520193 0.00218074]]
# Age : (4-6), conf = 0.733
# Gender : Female, conf = 0.999
# Age Output : [[9.94453847e-01 3.21138743e-03 1.40925799e-03 2.48490451e-05
#   5.37046813e-04 2.01704490e-04 6.03568769e-05 1.01569916e-04]]
# Age : (0-2), conf = 0.994
# Gender : Male, conf = 0.535
# Age Output : [[0.0017801  0.5818953  0.26607996 0.08193444 0.03135471 0.02778548
#   0.00623844 0.00293155]]
# Age : (4-6), conf = 0.582
# Gender : Female, conf = 1.000
# Age Output : [[9.9537140e-01 2.3019614e-03 1.6884506e-03 1.7102047e-05 3.1192377e-04
#   1.6850555e-04 4.1168620e-05 9.9425306e-05]]
# Age : (0-2), conf = 0.995
# Gender : Female, conf = 1.000
# Age Output : [[9.9317658e-01 3.2867291e-03 2.6195103e-03 2.7520924e-05 3.7857861e-04
#   2.7518559e-04 6.7841749e-05 1.6804611e-04]]
# Age : (0-2), conf = 0.993
# Gender : Female, conf = 0.999
# Age Output : [[9.9323928e-01 2.4434950e-03 2.9706999e-03 3.1265972e-05 5.1596062e-04
#   4.4683419e-04 9.3445800e-05 2.5897610e-04]]
# Age : (0-2), conf = 0.993
# Gender : Male, conf = 0.984
# Age Output : [[4.4186003e-04 1.9988908e-01 7.8857052e-01 5.4879389e-03 4.2527202e-03
#   5.8714981e-04 2.7553542e-04 4.9534545e-04]]
# Age : (8-12), conf = 0.789
# Gender : Female, conf = 0.999
# Age Output : [[9.9297994e-01 2.9240283e-03 2.7414549e-03 3.7763672e-05 7.2499795e-04
#   3.9030539e-04 7.4023257e-05 1.2748761e-04]]
# Age : (0-2), conf = 0.993
# Gender : Male, conf = 0.964
# Age Output : [[3.0797446e-04 2.3520257e-01 7.5359631e-01 5.9205079e-03 3.9361115e-03
#   4.4405757e-04 2.1323268e-04 3.7923557e-04]]
# Age : (8-12), conf = 0.754
# Gender : Female, conf = 0.999
# Age Output : [[9.8887211e-01 4.4166171e-03 5.4328898e-03 3.1710319e-05 8.2285650e-04
#   2.7827825e-04 5.7877129e-05 8.7689048e-05]]
# Age : (0-2), conf = 0.989
# Gender : Male, conf = 0.992
# Age Output : [[1.4821122e-03 3.5286900e-01 6.3166374e-01 6.4588641e-03 4.6766517e-03
#   9.6999365e-04 5.3568534e-04 1.3439348e-03]]
# Age : (8-12), conf = 0.632
# Gender : Female, conf = 0.999
# Age Output : [[9.9145573e-01 3.2885470e-03 4.3147327e-03 2.6121192e-05 5.4025190e-04
#   2.5121495e-04 3.9917017e-05 8.3371451e-05]]
# Age : (0-2), conf = 0.991
# Gender : Male, conf = 0.989
# Age Output : [[0.00120013 0.32224977 0.64356244 0.0216556  0.00752995 0.00155539
#   0.00064574 0.001601  ]]
# Age : (8-12), conf = 0.644
# Gender : Female, conf = 0.999
# Age Output : [[9.9130088e-01 3.2579233e-03 4.2607891e-03 3.1672334e-05 6.6875544e-04
#   3.2299507e-04 5.6125853e-05 1.0096190e-04]]
# Age : (0-2), conf = 0.991
# Gender : Male, conf = 0.931
# Age Output : [[1.2772657e-04 1.8248159e-01 7.9399490e-01 1.7773965e-02 4.6763774e-03
#   5.4190418e-04 1.3950899e-04 2.6403519e-04]]
# Age : (8-12), conf = 0.794
# Gender : Female, conf = 0.999
# Age Output : [[9.7807693e-01 4.8420765e-03 1.3742604e-02 6.8714187e-05 1.7682980e-03
#   9.3908526e-04 2.1052554e-04 3.5178132e-04]]
# Age : (0-2), conf = 0.978
# Gender : Male, conf = 0.897
# Age Output : [[9.7699281e-05 1.8974453e-01 7.7687323e-01 2.7602607e-02 4.7135921e-03
#   6.5438857e-04 9.7621611e-05 2.1637567e-04]]
# Age : (8-12), conf = 0.777
# Gender : Female, conf = 1.000
# Age Output : [[9.9249697e-01 2.7428165e-03 3.4526715e-03 3.1271367e-05 6.1332574e-04
#   4.1257840e-04 8.0594065e-05 1.6990851e-04]]
# Age : (0-2), conf = 0.992
# Gender : Male, conf = 0.927
# Age Output : [[1.6444313e-04 2.0772213e-01 7.6694006e-01 1.9521538e-02 4.2879903e-03
#   8.2692894e-04 1.4447744e-04 3.9241186e-04]]
# Age : (8-12), conf = 0.767
# Gender : Female, conf = 0.999
# Age Output : [[9.8345214e-01 4.6085515e-03 8.0568762e-03 7.8497280e-05 2.2771477e-03
#   1.0156910e-03 2.2362727e-04 2.8734197e-04]]
# Age : (0-2), conf = 0.983
# Gender : Male, conf = 0.950
# Age Output : [[1.6923959e-04 2.3336886e-01 7.2317833e-01 3.7214268e-02 4.3012868e-03
#   1.2197837e-03 1.4823068e-04 4.0008477e-04]]
# Age : (8-12), conf = 0.723
# Gender : Female, conf = 0.999
# Age Output : [[9.8609471e-01 3.6641266e-03 7.8587402e-03 4.9232574e-05 1.3166968e-03
#   6.5097946e-04 1.3983611e-04 2.2559390e-04]]
# Age : (0-2), conf = 0.986
# Gender : Male, conf = 0.977
# Age Output : [[3.6858980e-04 7.4691482e-02 8.9561677e-01 1.4012294e-02 9.7857928e-03
#   3.0605101e-03 8.5171562e-04 1.6127975e-03]]
# Age : (8-12), conf = 0.896
# Gender : Female, conf = 0.999
# Age Output : [[9.9298060e-01 3.7444050e-03 2.6723570e-03 1.8054949e-05 3.8261036e-04
#   1.2390273e-04 2.6890835e-05 5.1110164e-05]]
# Age : (0-2), conf = 0.993
# Gender : Male, conf = 0.945
# Age Output : [[6.4249279e-04 5.8137003e-02 8.8913256e-01 1.4712340e-02 1.7458271e-02
#   1.2293834e-02 3.5131581e-03 4.1103880e-03]]
# Age : (8-12), conf = 0.889
# Gender : Female, conf = 1.000
# Age Output : [[9.9779898e-01 1.2475572e-03 8.1264268e-04 4.8093425e-06 4.1682437e-05
#   4.7386511e-05 8.3866762e-06 3.8641716e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.994
# Age Output : [[0.0076821  0.16017237 0.75770354 0.00198081 0.02380957 0.02474286
#   0.0119643  0.01194431]]
# Age : (8-12), conf = 0.758
# Gender : Female, conf = 0.998
# Age Output : [[9.9735814e-01 1.3414756e-03 1.0449335e-03 9.4670113e-06 5.1440551e-05
#   9.6712996e-05 1.3957453e-05 8.3830033e-05]]
# Age : (0-2), conf = 0.997
# Gender : Male, conf = 0.992
# Age Output : [[0.01180377 0.28946614 0.66242445 0.00151429 0.00807888 0.01704916
#   0.0036619  0.00600144]]
# Age : (8-12), conf = 0.662
# Gender : Female, conf = 0.999
# Age Output : [[9.9240041e-01 3.5235337e-03 3.4359500e-03 2.4025388e-05 3.3862653e-04
#   1.7480933e-04 3.0407864e-05 7.2112307e-05]]
# Age : (0-2), conf = 0.992
# Gender : Male, conf = 0.993
# Age Output : [[0.020131   0.15448937 0.6842092  0.00212898 0.02241899 0.05751769
#   0.02808355 0.03102115]]
# Age : (8-12), conf = 0.684
# Gender : Female, conf = 1.000
# Age Output : [[9.9772149e-01 1.8306850e-03 3.5118021e-04 4.5538832e-06 5.5190496e-05
#   2.2292003e-05 3.8577541e-06 1.0790401e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.994
# Age Output : [[0.00500992 0.03455502 0.5112655  0.00453296 0.03921579 0.22476462
#   0.07953826 0.10111789]]
# Age : (8-12), conf = 0.511
# Gender : Female, conf = 0.999
# Age Output : [[9.9580896e-01 2.0872955e-03 1.6727309e-03 1.6811215e-05 1.9951866e-04
#   1.4021969e-04 1.9099556e-05 5.5300945e-05]]
# Age : (0-2), conf = 0.996
# Gender : Male, conf = 0.979
# Age Output : [[0.00307107 0.06038944 0.57600707 0.01038774 0.02265892 0.2156659
#   0.05606566 0.05575427]]
# Age : (8-12), conf = 0.576
# Gender : Female, conf = 1.000
# Age Output : [[9.9364257e-01 2.6969805e-03 2.5778566e-03 3.6991161e-05 4.8024874e-04
#   3.6769456e-04 6.3325511e-05 1.3430566e-04]]
# Age : (0-2), conf = 0.994
# Gender : Male, conf = 0.981
# Age Output : [[0.00545496 0.04772064 0.42802018 0.00954803 0.02423268 0.31313738
#   0.07450709 0.0973791 ]]
# Age : (8-12), conf = 0.428
# Gender : Female, conf = 1.000
# Age Output : [[9.9772161e-01 1.5119660e-03 5.8687007e-04 8.0932950e-06 7.5215772e-05
#   5.8428934e-05 9.9724975e-06 2.8002958e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.965
# Age Output : [[0.00391108 0.08503773 0.51494795 0.0132032  0.02480096 0.24718706
#   0.05859815 0.05231388]]
# Age : (8-12), conf = 0.515
# Gender : Female, conf = 1.000
# Age Output : [[9.9758244e-01 1.6014610e-03 5.7099492e-04 1.0158831e-05 1.0963027e-04
#   7.6430195e-05 1.4263348e-05 3.4551365e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.964
# Age Output : [[0.00604254 0.0722803  0.4586388  0.0075846  0.02300872 0.2841459
#   0.0690956  0.07920345]]
# Age : (8-12), conf = 0.459
# Gender : Female, conf = 1.000
# Age Output : [[9.9856770e-01 1.1916512e-03 1.8166787e-04 3.0272488e-06 2.9006536e-05
#   1.5657351e-05 2.5069671e-06 8.7261387e-06]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.957
# Age Output : [[0.00433181 0.18682906 0.53971267 0.01516983 0.01919679 0.1578765
#   0.04550571 0.03137756]]
# Age : (8-12), conf = 0.540
# Gender : Male, conf = 0.976
# Age Output : [[0.01476497 0.12667267 0.34428468 0.00793724 0.02197296 0.28154922
#   0.09444903 0.10836922]]
# Age : (8-12), conf = 0.344
# Gender : Female, conf = 0.998
# Age Output : [[9.9804735e-01 1.3616399e-03 4.2980976e-04 6.0485518e-06 7.8635152e-05
#   4.6072186e-05 7.5188627e-06 2.2892367e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.978
# Age Output : [[0.01373115 0.13185821 0.32808763 0.00711225 0.02105798 0.29137084
#   0.10547863 0.10130333]]
# Age : (8-12), conf = 0.328
# Gender : Female, conf = 1.000
# Age Output : [[9.9824983e-01 1.2705420e-03 3.7058984e-04 4.2826041e-06 5.2887011e-05
#   3.0695093e-05 4.6707810e-06 1.6515647e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.984
# Age Output : [[0.01380061 0.07055133 0.27253515 0.00604481 0.02196814 0.35825965
#   0.12559797 0.13124229]]
# Age : (38-43), conf = 0.358
# Gender : Female, conf = 1.000
# Age Output : [[9.9832588e-01 1.2526432e-03 3.2028265e-04 4.7650792e-06 4.0316394e-05
#   3.1098465e-05 4.8468773e-06 2.0068012e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.990
# Age Output : [[0.01365309 0.04415992 0.21877678 0.00549596 0.02416281 0.42107627
#   0.13541031 0.13726485]]
# Age : (38-43), conf = 0.421
# Gender : Female, conf = 1.000
# Age Output : [[9.9830085e-01 1.1553109e-03 4.0486004e-04 5.9118738e-06 4.9278759e-05
#   4.7168702e-05 6.9054649e-06 2.9774399e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.994
# Age Output : [[0.02880554 0.04883684 0.18812606 0.00510828 0.0239547  0.41266286
#   0.12502295 0.1674827 ]]
# Age : (38-43), conf = 0.413
# Gender : Female, conf = 1.000
# Age Output : [[9.9902427e-01 7.9310674e-04 1.4069848e-04 1.8742563e-06 1.5027053e-05
#   1.2228864e-05 2.0986331e-06 1.0655232e-05]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.994
# Age Output : [[0.01760866 0.03714865 0.20338602 0.00417434 0.02223238 0.4357329
#   0.12957281 0.15014417]]
# Age : (38-43), conf = 0.436
# Gender : Female, conf = 1.000
# Age Output : [[9.9876982e-01 9.6855260e-04 2.0128602e-04 2.8835761e-06 2.2175289e-05
#   1.8654418e-05 2.9767468e-06 1.3556638e-05]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.998
# Age Output : [[0.04105796 0.06015263 0.19814283 0.00505015 0.02502475 0.3748982
#   0.10987087 0.18580262]]
# Age : (38-43), conf = 0.375
# Gender : Female, conf = 1.000
# Age Output : [[9.9636805e-01 1.8564917e-03 1.1087361e-03 1.9938499e-05 2.9382680e-04
#   2.0785908e-04 3.7639107e-05 1.0737529e-04]]
# Age : (0-2), conf = 0.996
# Gender : Male, conf = 0.996
# Age Output : [[0.01971211 0.03558851 0.1626427  0.0042165  0.02911726 0.41860676
#   0.16742611 0.16269009]]
# Age : (38-43), conf = 0.419
# Gender : Female, conf = 1.000
# Age Output : [[9.9748224e-01 1.7070258e-03 5.8992521e-04 1.0191601e-05 8.1713726e-05
#   7.4247633e-05 1.2075014e-05 4.2600059e-05]]
# Age : (0-2), conf = 0.997
# Gender : Male, conf = 0.996
# Age Output : [[0.06645562 0.1282953  0.38187248 0.00398103 0.03535949 0.22812708
#   0.0767014  0.07920771]]
# Age : (8-12), conf = 0.382
# Gender : Female, conf = 0.999
# Age Output : [[9.8400038e-01 4.1891681e-03 6.3501932e-03 1.2261729e-04 2.9659679e-03
#   1.6794305e-03 2.7846568e-04 4.1381753e-04]]
# Age : (0-2), conf = 0.984
# Gender : Male, conf = 0.993
# Age Output : [[0.05653998 0.14415653 0.41160703 0.00345193 0.03401322 0.22656232
#   0.07047408 0.05319489]]
# Age : (8-12), conf = 0.412
# Gender : Female, conf = 1.000
# Age Output : [[9.9704713e-01 1.8714892e-03 7.3930813e-04 1.2895466e-05 1.5422788e-04
#   1.1048385e-04 1.7647566e-05 4.6851237e-05]]
# Age : (0-2), conf = 0.997
# Gender : Male, conf = 0.988
# Age Output : [[0.06559911 0.28949946 0.49791464 0.00209844 0.01901617 0.08183611
#   0.02189037 0.02214563]]
# Age : (8-12), conf = 0.498
# Gender : Female, conf = 0.999
# Age Output : [[9.97591138e-01 1.67163648e-03 4.92772378e-04 9.31713657e-06
#   1.23354184e-04 7.21945253e-05 1.11048785e-05 2.85957412e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.963
# Age Output : [[0.01241149 0.0995944  0.7800734  0.00223359 0.02767345 0.05105483
#   0.01194507 0.0150137 ]]
# Age : (8-12), conf = 0.780
# Gender : Female, conf = 0.998
# Age Output : [[9.9878901e-01 9.7240950e-04 1.5001978e-04 2.8675161e-06 5.5069129e-05
#   1.9327848e-05 3.2144239e-06 8.0765758e-06]]
# Age : (0-2), conf = 0.999
# Gender : Male, conf = 0.975
# Age Output : [[0.01397372 0.12379418 0.7820921  0.00203572 0.03053902 0.03166438
#   0.00770561 0.00819522]]
# Age : (8-12), conf = 0.782
# Gender : Female, conf = 0.998
# Age Output : [[9.9835312e-01 1.2579049e-03 2.2996587e-04 5.1881025e-06 1.0163695e-04
#   3.3941000e-05 5.7740972e-06 1.2528646e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.968
# Age Output : [[0.02747281 0.1598562  0.76281804 0.00107921 0.01096392 0.02087979
#   0.00594764 0.0109824 ]]
# Age : (8-12), conf = 0.763
# Gender : Female, conf = 0.999
# Age Output : [[9.9826765e-01 1.3309531e-03 2.7098515e-04 5.3080066e-06 7.5890493e-05
#   3.1517626e-05 4.7498511e-06 1.2830223e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.967
# Age Output : [[0.01941412 0.16035514 0.7642525  0.00154816 0.01561253 0.02385749
#   0.00492757 0.01003253]]
# Age : (8-12), conf = 0.764
# Gender : Female, conf = 1.000
# Age Output : [[9.9742657e-01 1.8351132e-03 4.8833550e-04 9.8672172e-06 1.3238727e-04
#   7.0799186e-05 1.0326782e-05 2.6656531e-05]]
# Age : (0-2), conf = 0.997
# Gender : Female, conf = 1.000
# Age Output : [[9.9761885e-01 1.6764370e-03 4.6863474e-04 9.8611763e-06 1.2104697e-04
#   6.9261383e-05 9.1565325e-06 2.6640477e-05]]
# Age : (0-2), conf = 0.998
# Gender : Male, conf = 0.784
# Age Output : [[0.00677051 0.13509041 0.80685145 0.00285934 0.02645607 0.01251973
#   0.00325519 0.00619738]]
# Age : (8-12), conf = 0.807
# Gender : Male, conf = 0.750
# Age Output : [[0.00220074 0.16102363 0.8099904  0.00281961 0.01674406 0.00399807
#   0.00149643 0.00172693]]
# Age : (8-12), conf = 0.810
# Gender : Female, conf = 0.999
# Age Output : [[9.9631602e-01 2.2690294e-03 8.5239665e-04 1.8574592e-05 3.2699606e-04
#   1.5287638e-04 2.0205547e-05 4.4118016e-05]]
# Age : (0-2), conf = 0.996
# Gender : Female, conf = 0.999
# Age Output : [[9.9829739e-01 1.0253937e-03 5.0568802e-04 6.7333403e-06 7.0200440e-05
#   6.2301566e-05 6.5885179e-06 2.5751116e-05]]
# Age : (0-2), conf = 0.998
# Gender : Female, conf = 0.622
# Age Output : [[1.0338182e-03 6.0995501e-01 3.7952530e-01 3.0551194e-03 4.9441550e-03
#   1.0321330e-03 2.1253976e-04 2.4183141e-04]]
# Age : (4-6), conf = 0.610
# Gender : Female, conf = 0.999
# Age Output : [[9.9767953e-01 1.3752060e-03 6.4901443e-04 1.0124006e-05 1.3489347e-04
#   1.0078159e-04 1.2927978e-05 3.7524103e-05]]
# Age : (0-2), conf = 0.998
# Gender : Female, conf = 0.603
# Age Output : [[0.00231305 0.21062678 0.7237102  0.00403531 0.05165735 0.00399853
#   0.00168998 0.0019688 ]]
# Age : (8-12), conf = 0.724
# Gender : Female, conf = 0.996
# Age Output : [[9.8990309e-01 2.4780254e-03 3.8265493e-03 6.2829778e-05 1.5059498e-03
#   1.5134905e-03 2.3027608e-04 4.7984510e-04]]
# Age : (0-2), conf = 0.990
# Gender : Male, conf = 0.615
# Age Output : [[0.00113639 0.09066521 0.800668   0.00377076 0.09658645 0.00372952
#   0.001518   0.00192585]]
# Age : (8-12), conf = 0.801
# Gender : Female, conf = 0.998
# Age Output : [[9.8154771e-01 3.6231338e-03 6.4861835e-03 1.4415888e-04 3.5915335e-03
#   3.1955913e-03 4.4625747e-04 9.6540339e-04]]
# Age : (0-2), conf = 0.982
# Gender : Male, conf = 0.883
# Age Output : [[6.5148401e-04 4.0485531e-02 8.0467892e-01 7.9004802e-03 1.2961540e-01
#   9.5959837e-03 2.7209942e-03 4.3511381e-03]]
# Age : (8-12), conf = 0.805
# Gender : Female, conf = 0.998
# Age Output : [[9.9087662e-01 3.1573698e-03 2.8920972e-03 6.7348396e-05 1.6661873e-03
#   9.4517582e-04 1.3483310e-04 2.6028341e-04]]
# Age : (0-2), conf = 0.991
# Gender : Male, conf = 0.965
# Age Output : [[3.0798325e-04 1.5201846e-02 5.9189194e-01 1.5261590e-02 3.4679979e-01
#   2.0380048e-02 3.2939510e-03 6.8628588e-03]]
# Age : (8-12), conf = 0.592
# Gender : Female, conf = 0.999
# Age Output : [[9.9329799e-01 2.7233339e-03 2.0037256e-03 4.1033381e-05 1.0959004e-03
#   5.2430877e-04 9.6490978e-05 2.1712072e-04]]
# Age : (0-2), conf = 0.993
# Gender : Male, conf = 0.995
# Age Output : [[4.4958867e-04 2.5449747e-02 5.9188342e-01 5.7380382e-02 2.8430432e-01
#   3.0892059e-02 2.1996072e-03 7.4408995e-03]]
# Age : (8-12), conf = 0.592
# Gender : Female, conf = 0.998
# Age Output : [[9.9310780e-01 2.5869000e-03 2.5659888e-03 3.7231541e-05 8.8130863e-04
#   5.0480315e-04 8.0302001e-05 2.3581997e-04]]
# Age : (0-2), conf = 0.993
# Gender : Male, conf = 0.994
# Age Output : [[0.00127515 0.09917931 0.30901238 0.40012124 0.13619572 0.0490608
#   0.00182809 0.00332735]]
# Age : (15-20), conf = 0.400
# Gender : Female, conf = 0.998
# Age Output : [[9.95671391e-01 2.00956501e-03 1.58767309e-03 1.79998551e-05
#   3.72799550e-04 2.10501195e-04 2.65187318e-05 1.03583036e-04]]
# Age : (0-2), conf = 0.996
# Gender : Female, conf = 0.998
# Age Output : [[9.7929013e-01 5.1367604e-03 1.2590201e-02 7.6383651e-05 1.4797976e-03
#   9.2179852e-04 9.1432317e-05 4.1352306e-04]]
# Age : (0-2), conf = 0.979
# Gender : Female, conf = 0.999
# Age Output : [[9.12864327e-01 1.47302905e-02 4.69017178e-02 3.52930074e-04
#   2.01622490e-02 3.57526098e-03 5.56592771e-04 8.56749597e-04]]
# Age : (0-2), conf = 0.913
# Gender : Female, conf = 0.999
# Age Output : [[0.10385769 0.00733884 0.7459658  0.0013744  0.04585904 0.09084347
#   0.00224025 0.00252049]]
# Age : (8-12), conf = 0.746
# Gender : Female, conf = 0.999
# Age Output : [[0.58984995 0.00774937 0.29011676 0.00099643 0.03400835 0.06778077
#   0.00286859 0.00662979]]
# Age : (0-2), conf = 0.590
# Gender : Female, conf = 0.998
# Age Output : [[7.1896583e-01 7.7396207e-03 1.7767873e-01 5.1283266e-04 7.0775256e-02
#   1.7916139e-02 2.1466415e-03 4.2648907e-03]]
# Age : (0-2), conf = 0.719
# Gender : Female, conf = 0.991
# Age Output : [[0.14596808 0.00371839 0.298033   0.00153128 0.50100833 0.03318048
#   0.00633597 0.01022447]]
# Age : (25-32), conf = 0.501
# Gender : Female, conf = 0.975
# Age Output : [[6.2405777e-01 9.2101656e-03 6.0367554e-02 5.2584586e-04 2.9523543e-01
#   7.1133454e-03 2.0011570e-03 1.4887371e-03]]
# Age : (0-2), conf = 0.624
# Gender : Female, conf = 0.974
# Age Output : [[8.8788593e-01 8.8111805e-03 1.2177640e-02 2.2184935e-04 8.6717248e-02
#   2.6724332e-03 8.9406548e-04 6.1963935e-04]]
# Age : (0-2), conf = 0.888
# Gender : Female, conf = 0.970
# Age Output : [[8.7658107e-01 1.1471352e-02 1.0622333e-02 2.4596445e-04 9.7364962e-02
#   2.4436326e-03 8.7064516e-04 4.0015636e-04]]
# Age : (0-2), conf = 0.877
# Gender : Female, conf = 0.984
# Age Output : [[7.1177105e-03 2.3677845e-03 1.8437782e-02 4.4048956e-04 9.6696401e-01
#   2.9821740e-03 1.5322048e-03 1.5797369e-04]]
# Age : (25-32), conf = 0.967
# Gender : Female, conf = 0.949
# Age Output : [[0.19483694 0.01656221 0.02424352 0.0015094  0.7433689  0.01237891
#   0.00586061 0.0012395 ]]
# Age : (25-32), conf = 0.743
# Gender : Female, conf = 0.952
# Age Output : [[0.13807732 0.00834103 0.01963047 0.00109234 0.8162999  0.0116795
#   0.00394197 0.00093751]]
# Age : (25-32), conf = 0.816
# Gender : Female, conf = 0.927
# Age Output : [[0.35897928 0.0099712  0.01951811 0.00072968 0.5968797  0.00904028
#   0.00395316 0.00092857]]
# Age : (25-32), conf = 0.597
# Gender : Female, conf = 0.950
# Age Output : [[0.30058032 0.01990934 0.01806262 0.00150437 0.6403771  0.01319072
#   0.00527797 0.00109756]]
# Age : (25-32), conf = 0.640
# Gender : Female, conf = 0.953
# Age Output : [[0.12796506 0.01887105 0.01557631 0.0020307  0.80936205 0.01473744
#   0.01022254 0.00123482]]
# Age : (25-32), conf = 0.809
# Gender : Female, conf = 0.993
# Age Output : [[4.2907599e-02 1.7994134e-02 2.0173611e-02 2.2523177e-03 8.9863408e-01
#   1.0259319e-02 7.1173683e-03 6.6152803e-04]]
# Age : (25-32), conf = 0.899
# Gender : Female, conf = 0.985
# Age Output : [[0.1410057  0.06622028 0.03630572 0.00267337 0.7310456  0.01043193
#   0.01145793 0.00085942]]
# Age : (25-32), conf = 0.731
# Gender : Female, conf = 0.994
# Age Output : [[0.28406757 0.05611218 0.05894274 0.00198839 0.58326054 0.00759589
#   0.00721334 0.00081935]]
# Age : (25-32), conf = 0.583
# Gender : Female, conf = 0.997
# Age Output : [[0.40090665 0.05208225 0.05105945 0.00128984 0.4746048  0.00856062
#   0.01058069 0.00091572]]
# Age : (25-32), conf = 0.475
# Gender : Female, conf = 0.995
# Age Output : [[0.30581513 0.03027216 0.06349583 0.00122903 0.5603055  0.02001408
#   0.01751614 0.00135212]]
# Age : (25-32), conf = 0.560
# Gender : Female, conf = 0.996
# Age Output : [[0.28967863 0.02288262 0.0504706  0.00143213 0.5658825  0.0386172
#   0.02916537 0.0018709 ]]
# Age : (25-32), conf = 0.566
# Gender : Female, conf = 0.993
# Age Output : [[0.09882489 0.01647328 0.19644602 0.00124605 0.62065536 0.03847132
#   0.02632011 0.00156297]]
# Age : (25-32), conf = 0.621
# Gender : Female, conf = 0.996
# Age Output : [[0.12968522 0.01203792 0.08342643 0.00136973 0.6827017  0.04491018
#   0.04382452 0.00204426]]
# Age : (25-32), conf = 0.683
# Gender : Female, conf = 0.991
# Age Output : [[0.07230152 0.00604399 0.02249564 0.00105118 0.84829295 0.02711362
#   0.02165075 0.00105038]]
# Age : (25-32), conf = 0.848
# Gender : Female, conf = 0.991
# Age Output : [[0.10079404 0.01620892 0.02713438 0.00177507 0.7758301  0.04063559
#   0.03597081 0.00165104]]
# Age : (25-32), conf = 0.776
# Gender : Female, conf = 0.995
# Age Output : [[0.00996128 0.0037783  0.23998894 0.00138308 0.6894871  0.03156357
#   0.02278567 0.00105202]]
# Age : (25-32), conf = 0.689
# Gender : Female, conf = 0.994
# Age Output : [[0.07735566 0.01467245 0.10400885 0.00152467 0.7328042  0.03625301
#   0.03169252 0.00168869]]
# Age : (25-32), conf = 0.733
# Gender : Female, conf = 0.996
# Age Output : [[0.06054444 0.00523311 0.04391193 0.0015117  0.807755   0.04950449
#   0.0299355  0.00160387]]
# Age : (25-32), conf = 0.808
# Gender : Female, conf = 0.985
# Age Output : [[0.50177455 0.04063283 0.02256263 0.0012079  0.40543762 0.01331615
#   0.01393776 0.0011305 ]]
# Age : (0-2), conf = 0.502
# Gender : Female, conf = 0.998
# Age Output : [[0.5371812  0.05458798 0.01105743 0.00126734 0.36747238 0.01154639
#   0.01575945 0.00112781]]
# Age : (0-2), conf = 0.537
# Gender : Female, conf = 0.999
# Age Output : [[0.5581979  0.03804515 0.00773389 0.00182352 0.35281348 0.02015849
#   0.0193466  0.00188099]]
# Age : (0-2), conf = 0.558
# Gender : Female, conf = 1.000
# Age Output : [[0.6472856  0.04121201 0.00707468 0.00160227 0.26021454 0.02009661
#   0.02062318 0.00189109]]
# Age : (0-2), conf = 0.647
# Gender : Female, conf = 0.999
# Age Output : [[0.44052988 0.03796439 0.01025595 0.00236799 0.43983912 0.03464472
#   0.03189791 0.00250007]]
# Age : (0-2), conf = 0.441
# Gender : Female, conf = 0.999
# Age Output : [[0.69799966 0.02071293 0.00583501 0.00089774 0.2409644  0.01739566
#   0.01438376 0.00181086]]
# Age : (0-2), conf = 0.698
# Gender : Female, conf = 0.999
# Age Output : [[9.1688007e-01 1.4625171e-02 5.5782837e-03 3.2943705e-04 5.3995851e-02
#   3.9093895e-03 3.9129741e-03 7.6892151e-04]]
# Age : (0-2), conf = 0.917
# Gender : Female, conf = 0.999
# Age Output : [[9.2609918e-01 1.4411872e-02 7.0358803e-03 2.9982391e-04 4.5162607e-02
#   3.1725022e-03 3.1577540e-03 6.6024612e-04]]
# Age : (0-2), conf = 0.926
# Gender : Female, conf = 0.999
# Age Output : [[0.3847796  0.0419681  0.02902701 0.00166592 0.5047616  0.01669434
#   0.01964013 0.00146339]]
# Age : (25-32), conf = 0.505
# Gender : Female, conf = 0.997
# Age Output : [[8.4105814e-01 4.4478942e-02 1.7208902e-02 5.3758326e-04 8.9227870e-02
#   3.4928527e-03 3.4771094e-03 5.1861559e-04]]
# Age : (0-2), conf = 0.841
# Gender : Female, conf = 0.998
# Age Output : [[0.52833515 0.04359842 0.03609611 0.00137957 0.37313938 0.01110721
#   0.00527428 0.0010699 ]]
# Age : (0-2), conf = 0.528
# Gender : Female, conf = 0.998
# Age Output : [[0.79505897 0.04051116 0.01629066 0.00092956 0.13424918 0.00753884
#   0.00457766 0.00084395]]
# Age : (0-2), conf = 0.795
# Gender : Female, conf = 0.999
# Age Output : [[8.1705731e-01 4.1407220e-02 1.8232899e-02 7.6356228e-04 1.1318806e-01
#   4.9410011e-03 3.7280377e-03 6.8188453e-04]]
# Age : (0-2), conf = 0.817
# Gender : Female, conf = 0.987
# Age Output : [[0.6490533  0.02811568 0.01687378 0.00113825 0.27975813 0.01503342
#   0.00888696 0.00114051]]
# Age : (0-2), conf = 0.649
# Gender : Female, conf = 0.994
# Age Output : [[0.6953427  0.02673314 0.02721502 0.0014259  0.2258819  0.01533054
#   0.00693926 0.00113167]]
# Age : (0-2), conf = 0.695
# Gender : Female, conf = 0.994
# Age Output : [[0.29023796 0.04742797 0.09643793 0.00249002 0.52350426 0.02572926
#   0.01279465 0.00137795]]
# Age : (25-32), conf = 0.524
# Gender : Female, conf = 0.991
# Age Output : [[0.17309766 0.01457937 0.04712207 0.00222118 0.72405297 0.02635076
#   0.01147695 0.00109905]]
# Age : (25-32), conf = 0.724
# Gender : Female, conf = 0.999
# Age Output : [[0.49463746 0.04549788 0.01994186 0.00202216 0.41047314 0.01552257
#   0.01060509 0.0012998 ]]
# Age : (0-2), conf = 0.495
# Gender : Female, conf = 0.999
# Age Output : [[0.32996523 0.03419    0.01417855 0.00257058 0.5884728  0.01994471
#   0.00935593 0.00132222]]
# Age : (25-32), conf = 0.588
# Gender : Female, conf = 0.999
# Age Output : [[0.6110473  0.03803116 0.01052814 0.00193996 0.31895137 0.01312796
#   0.00529729 0.00107676]]
# Age : (0-2), conf = 0.611
# Gender : Female, conf = 0.999
# Age Output : [[0.60454357 0.02990165 0.01072633 0.00197738 0.32752213 0.01785475
#   0.00610213 0.00137206]]
# Age : (0-2), conf = 0.605
# Gender : Female, conf = 0.999
# Age Output : [[0.38645187 0.02640606 0.01497503 0.00263002 0.5350619  0.02359147
#   0.00954265 0.00134105]]
# Age : (25-32), conf = 0.535
# Gender : Female, conf = 1.000
# Age Output : [[0.6196509  0.03765228 0.01094962 0.00195863 0.3084262  0.01305741
#   0.00721576 0.00108927]]
# Age : (0-2), conf = 0.620
# Gender : Female, conf = 1.000
# Age Output : [[0.66129994 0.03586585 0.01253861 0.00190889 0.269843   0.01198654
#   0.0056476  0.00090949]]
# Age : (0-2), conf = 0.661
# Gender : Female, conf = 0.999
# Age Output : [[0.37301928 0.01553356 0.0182949  0.00257894 0.54937375 0.03236267
#   0.00750254 0.00133435]]
# Age : (25-32), conf = 0.549
# Gender : Female, conf = 1.000
# Age Output : [[0.67042714 0.03207553 0.01011181 0.00178622 0.26212013 0.01617344
#   0.00603298 0.00127278]]
# Age : (0-2), conf = 0.670
# Gender : Female, conf = 1.000
# Age Output : [[0.619589   0.0330919  0.01105098 0.00214137 0.30601755 0.01930077
#   0.0073857  0.0014228 ]]
# Age : (0-2), conf = 0.620
# Gender : Female, conf = 0.999
# Age Output : [[0.5448888  0.0220267  0.01492718 0.00302149 0.3779685  0.03058363
#   0.00537283 0.00121088]]
# Age : (0-2), conf = 0.545
# Gender : Female, conf = 1.000
# Age Output : [[0.5328925  0.0210354  0.01227574 0.00337727 0.38565603 0.03706906
#   0.00633287 0.00136111]]
# Age : (0-2), conf = 0.533
# Gender : Female, conf = 1.000
# Age Output : [[0.7325077  0.03930577 0.00799591 0.00192698 0.19965658 0.01302823
#   0.004585   0.00099384]]
# Age : (0-2), conf = 0.733
# Gender : Female, conf = 1.000
# Age Output : [[8.7373161e-01 3.5669893e-02 3.9408691e-03 7.5131643e-04 7.9715811e-02
#   3.7658189e-03 1.9839103e-03 4.4088389e-04]]
# Age : (0-2), conf = 0.874
# Gender : Female, conf = 0.999
# Age Output : [[0.76377624 0.05211068 0.00767153 0.00176438 0.1615232  0.00878302
#   0.00360482 0.00076626]]
# Age : (0-2), conf = 0.764
# Gender : Female, conf = 0.999
# Age Output : [[8.5508800e-01 4.2223975e-02 4.6938979e-03 1.0250435e-03 8.9742139e-02
#   4.7520790e-03 1.8971349e-03 5.7779113e-04]]
# Age : (0-2), conf = 0.855
# Gender : Female, conf = 0.999
# Age Output : [[7.9691958e-01 6.0286105e-02 5.3304941e-03 1.1716319e-03 1.2949967e-01
#   4.0308484e-03 2.2260698e-03 5.3571857e-04]]
# Age : (0-2), conf = 0.797
# Gender : Female, conf = 0.999
# Age Output : [[8.9227182e-01 4.7475748e-02 2.5947103e-03 5.3470122e-04 5.4353647e-02
#   1.5472739e-03 9.7097026e-04 2.5104434e-04]]
# Age : (0-2), conf = 0.892
# Gender : Female, conf = 0.999
# Age Output : [[0.7263082  0.01310775 0.01654523 0.00265361 0.20718455 0.03039839
#   0.00264149 0.0011607 ]]
# Age : (0-2), conf = 0.726
# Gender : Female, conf = 0.999
# Age Output : [[8.1398487e-01 7.5642787e-02 6.2809363e-03 8.8886591e-04 9.9619433e-02
#   2.0342388e-03 1.2571774e-03 2.9172437e-04]]
# Age : (0-2), conf = 0.814
# Gender : Female, conf = 0.999
# Age Output : [[7.9884583e-01 4.5902282e-02 7.6549491e-03 1.3013291e-03 1.3836668e-01
#   5.3238063e-03 2.1056093e-03 4.9952295e-04]]
# Age : (0-2), conf = 0.799
# Gender : Female, conf = 0.999
# Age Output : [[0.16814554 0.0112486  0.02983439 0.00875221 0.6552949  0.1156335
#   0.00919114 0.00189973]]
# Age : (25-32), conf = 0.655
# Gender : Female, conf = 0.956
# Age Output : [[0.05376878 0.00523139 0.0134857  0.00565138 0.85148674 0.06085189
#   0.00824158 0.00128251]]
# Age : (25-32), conf = 0.851
# Gender : Female, conf = 0.987
# Age Output : [[0.04917053 0.00345993 0.01383203 0.00348009 0.85749686 0.06355017
#   0.0077797  0.0012307 ]]
# Age : (25-32), conf = 0.857
# Gender : Female, conf = 0.999
# Age Output : [[9.0044534e-01 2.9443659e-02 6.4880634e-03 8.3584042e-04 5.6642376e-02
#   4.6398500e-03 1.1659984e-03 3.3888782e-04]]
# Age : (0-2), conf = 0.900
# Gender : Female, conf = 0.999
# Age Output : [[8.7776005e-01 5.0309125e-02 8.4457276e-03 1.1337925e-03 5.7675716e-02
#   3.4355589e-03 9.4709796e-04 2.9308413e-04]]
# Age : (0-2), conf = 0.878
# Gender : Female, conf = 0.999
# Age Output : [[6.8608141e-01 6.2452238e-02 3.3562638e-02 2.5115989e-03 2.0266907e-01
#   9.7298631e-03 2.3435897e-03 6.4965896e-04]]
# Age : (0-2), conf = 0.686
# Gender : Female, conf = 0.999
# Age Output : [[0.5563132  0.06318567 0.0430758  0.00306078 0.31627142 0.01376919
#   0.00350711 0.00081692]]
# Age : (0-2), conf = 0.556
# Gender : Female, conf = 0.999
# Age Output : [[0.36858177 0.05995234 0.10024896 0.00340413 0.45195922 0.01270173
#   0.00246522 0.00068654]]
# Age : (25-32), conf = 0.452
# Gender : Female, conf = 0.968
# Age Output : [[9.9844942e-03 1.2480440e-03 1.3496388e-02 3.6920409e-03 8.9172333e-01
#   7.2502881e-02 6.8511548e-03 5.0173659e-04]]
# Age : (25-32), conf = 0.892
# Gender : Female, conf = 0.999
# Age Output : [[0.10671709 0.027102   0.11818471 0.00403583 0.71861356 0.02172663
#   0.00288297 0.00073728]]
# Age : (25-32), conf = 0.719
# Gender : Female, conf = 0.999
# Age Output : [[0.16873783 0.03408745 0.12891963 0.00492147 0.6377806  0.02225696
#   0.00247711 0.00081893]]
# Age : (25-32), conf = 0.638
# Gender : Female, conf = 0.999
# Age Output : [[0.16640723 0.0299012  0.14280485 0.00452397 0.6320683  0.02108456
#   0.00229762 0.00091227]]
# Age : (25-32), conf = 0.632
# Gender : Female, conf = 0.998
# Age Output : [[0.13148198 0.02755449 0.133718   0.00559991 0.6726554  0.02569269
#   0.00238916 0.00090839]]
# Age : (25-32), conf = 0.673
# Gender : Female, conf = 0.998
# Age Output : [[0.12162614 0.02657473 0.14656623 0.00458705 0.66927123 0.02699198
#   0.00333764 0.001045  ]]
# Age : (25-32), conf = 0.669
# Gender : Female, conf = 0.999
# Age Output : [[0.24510437 0.03958267 0.15466103 0.00370909 0.53373617 0.01836906
#   0.00354593 0.00129166]]
# Age : (25-32), conf = 0.534
# Gender : Female, conf = 0.998
# Age Output : [[0.08687258 0.01757619 0.10922836 0.00450618 0.7432244  0.0343133
#   0.00317608 0.00110297]]
# Age : (25-32), conf = 0.743
# Gender : Female, conf = 0.996
# Age Output : [[0.11858238 0.00694406 0.13686052 0.00085259 0.70520073 0.02454422
#   0.00601224 0.00100325]]
# Age : (25-32), conf = 0.705
# Gender : Female, conf = 0.994
# Age Output : [[6.36993498e-02 3.22360219e-03 1.22996785e-01 6.83747872e-04
#   7.77871966e-01 2.60232277e-02 4.66153398e-03 8.39732238e-04]]
# Age : (25-32), conf = 0.778
# Gender : Female, conf = 0.998
# Age Output : [[1.0687166e-01 7.0311921e-03 1.4148405e-01 6.9709303e-04 7.1942067e-01
#   1.8914994e-02 4.6365932e-03 9.4380626e-04]]
# Age : (25-32), conf = 0.719
# Gender : Female, conf = 0.999
# Age Output : [[0.05913702 0.00465853 0.13389513 0.00080987 0.7694599  0.02597631
#   0.00479956 0.00126361]]
# Age : (25-32), conf = 0.769
# Gender : Female, conf = 0.999
# Age Output : [[0.30291843 0.01813765 0.1656186  0.00121258 0.48282564 0.02334164
#   0.00373052 0.00221495]]
# Age : (25-32), conf = 0.483
# Gender : Female, conf = 0.999
# Age Output : [[2.5371561e-02 3.0873870e-03 9.4796479e-02 7.6729275e-04 8.4599096e-01
#   2.6137562e-02 3.0935097e-03 7.5530371e-04]]
# Age : (25-32), conf = 0.846
# Gender : Female, conf = 0.998
# Age Output : [[0.08643546 0.00802152 0.1741967  0.00078371 0.70495725 0.02122564
#   0.00326141 0.00111827]]
# Age : (25-32), conf = 0.705
# Gender : Female, conf = 0.997
# Age Output : [[0.1515937  0.0085431  0.18781859 0.00115711 0.62239766 0.02290354
#   0.00413406 0.00145227]]
# Age : (25-32), conf = 0.622
# Gender : Female, conf = 0.998
# Age Output : [[0.28524643 0.02801078 0.23681714 0.00141842 0.42963973 0.01519347
#   0.0024373  0.00123678]]
# Age : (25-32), conf = 0.430
# Gender : Female, conf = 0.993
# Age Output : [[0.2015569  0.01356078 0.02473684 0.00302185 0.6852039  0.06400087
#   0.00611037 0.00180842]]
# Age : (25-32), conf = 0.685
# Gender : Female, conf = 0.998
# Age Output : [[0.65836895 0.02686595 0.01779645 0.00224143 0.2676928  0.02273777
#   0.00310074 0.00119603]]
# Age : (0-2), conf = 0.658
# Gender : Female, conf = 0.999
# Age Output : [[0.77408034 0.0274436  0.01021543 0.00146976 0.17315418 0.01039621
#   0.00237933 0.00086112]]
# Age : (0-2), conf = 0.774
# Gender : Female, conf = 0.999
# Age Output : [[0.4542738  0.05371506 0.06274008 0.00444976 0.40880325 0.01221773
#   0.00302644 0.00077394]]
# Age : (0-2), conf = 0.454
# Gender : Female, conf = 0.999
# Age Output : [[2.9448811e-02 1.1213276e-02 2.8105026e-01 3.0470383e-03 6.6326439e-01
#   9.7358543e-03 1.8464640e-03 3.9387943e-04]]
# Age : (25-32), conf = 0.663
# Gender : Female, conf = 1.000
# Age Output : [[2.7664665e-03 2.6198041e-03 9.2107855e-02 1.4362811e-03 8.9489150e-01
#   5.1354580e-03 9.1876736e-04 1.2399869e-04]]
# Age : (25-32), conf = 0.895
# Gender : Female, conf = 0.999
# Age Output : [[1.83099555e-03 1.73816213e-03 1.34507969e-01 1.57798035e-03
#   8.54985237e-01 4.37372876e-03 8.74628779e-04 1.11401925e-04]]
# Age : (25-32), conf = 0.855
# Gender : Female, conf = 0.999
# Age Output : [[6.0579652e-04 4.4937959e-04 9.4563872e-02 8.2280545e-04 8.9927906e-01
#   3.5391655e-03 6.7297387e-04 6.6869863e-05]]
# Age : (25-32), conf = 0.899
# Gender : Female, conf = 0.999
# Age Output : [[1.9230763e-04 1.4037639e-04 1.0206758e-01 5.8714935e-04 8.9211613e-01
#   4.2351414e-03 6.0729176e-04 5.4168126e-05]]
# Age : (25-32), conf = 0.892
# Gender : Male, conf = 0.994
# Age Output : [[0.05210038 0.57413936 0.36066324 0.00095567 0.00200995 0.00738352
#   0.00169399 0.00105385]]
# Age : (4-6), conf = 0.574
# Gender : Female, conf = 0.997
# Age Output : [[8.1764307e-04 1.2766005e-03 1.7432091e-01 6.2385161e-04 8.2020891e-01
#   1.9880538e-03 6.9258962e-04 7.1455011e-05]]
# Age : (25-32), conf = 0.820
# Gender : Female, conf = 0.998
# Age Output : [[2.0142637e-04 5.6889263e-04 1.4952791e-01 4.1734730e-04 8.4675407e-01
#   1.9090077e-03 5.6753441e-04 5.3903706e-05]]
# Age : (25-32), conf = 0.847
# Gender : Female, conf = 0.998
# Age Output : [[6.0048609e-05 2.8217334e-04 1.4003608e-01 3.5984191e-04 8.5677564e-01
#   1.7326575e-03 7.0486049e-04 4.8720129e-05]]
# Age : (25-32), conf = 0.857
# Gender : Female, conf = 0.999
# Age Output : [[4.3887616e-05 4.0098963e-05 2.8129146e-02 1.6864018e-04 9.6809667e-01
#   2.6315660e-03 8.4113766e-04 4.8735797e-05]]
# Age : (25-32), conf = 0.968
# Gender : Female, conf = 0.999
# Age Output : [[2.1432704e-06 1.7775025e-06 1.1316915e-02 8.9889349e-05 9.8553771e-01
#   2.4654786e-03 5.5175059e-04 3.4392826e-05]]
# Age : (25-32), conf = 0.986
# Gender : Female, conf = 0.999
# Age Output : [[2.3706667e-05 3.4305111e-05 6.6393822e-02 1.7805563e-04 9.2967612e-01
#   2.3358546e-03 1.2959740e-03 6.2086205e-05]]
# Age : (25-32), conf = 0.930
# Gender : Female, conf = 0.999
# Age Output : [[1.5429416e-04 1.7044316e-04 9.6950404e-02 2.0146220e-04 8.9990437e-01
#   1.5214293e-03 9.9973741e-04 9.7931414e-05]]
# Age : (25-32), conf = 0.900
# Gender : Female, conf = 1.000
# Age Output : [[4.4619719e-06 3.2149374e-06 1.1507141e-02 5.6008143e-05 9.8667485e-01
#   1.2698857e-03 4.5079389e-04 3.3656161e-05]]
# Age : (25-32), conf = 0.987
# Gender : Female, conf = 0.999
# Age Output : [[9.3103801e-05 1.4455069e-04 1.1166750e-01 1.4277041e-04 8.8580024e-01
#   1.2215289e-03 8.5170864e-04 7.8582103e-05]]
# Age : (25-32), conf = 0.886
# Gender : Female, conf = 0.999
# Age Output : [[9.4785508e-05 7.8844758e-05 8.5843123e-02 1.5666526e-04 9.1042590e-01
#   1.7651736e-03 1.5431002e-03 9.2424300e-05]]
# Age : (25-32), conf = 0.910
# Gender : Female, conf = 0.999
# Age Output : [[1.5578444e-05 4.8105027e-05 7.9356402e-02 1.7173178e-04 9.1847074e-01
#   1.3063650e-03 5.9316662e-04 3.7843234e-05]]
# Age : (25-32), conf = 0.918
# Gender : Female, conf = 0.997
# Age Output : [[1.6180076e-05 1.4786339e-04 3.5027117e-01 3.3830095e-04 6.4763045e-01
#   1.1302121e-03 4.2153319e-04 4.4331828e-05]]
# Age : (25-32), conf = 0.648
# Gender : Female, conf = 0.999
# Age Output : [[1.2082033e-05 5.9688726e-05 1.7703514e-01 2.0041104e-04 8.2109636e-01
#   1.1355366e-03 4.2643788e-04 3.4254866e-05]]
# Age : (25-32), conf = 0.821
# Gender : Female, conf = 0.999
# Age Output : [[4.8286711e-07 7.1194449e-07 3.6555994e-03 3.8089674e-05 9.9550062e-01
#   6.8221515e-04 1.1159269e-04 1.0669573e-05]]
# Age : (25-32), conf = 0.996
# Gender : Female, conf = 0.999
# Age Output : [[3.7896559e-06 8.0053596e-06 2.6059831e-02 1.3207860e-04 9.7243881e-01
#   1.0336287e-03 2.9180522e-04 3.2054075e-05]]
# Age : (25-32), conf = 0.972
# Gender : Female, conf = 0.998
# Age Output : [[1.15221965e-05 1.91759882e-05 2.78946124e-02 2.04519485e-04
#   9.69572425e-01 1.89304410e-03 3.51408205e-04 5.33991952e-05]]
# Age : (25-32), conf = 0.970
# Gender : Female, conf = 0.999
# Age Output : [[2.1137648e-05 8.5893997e-05 1.3635403e-01 3.4149602e-04 8.5989875e-01
#   2.6177436e-03 5.8162009e-04 9.9332872e-05]]
# Age : (25-32), conf = 0.860
# Gender : Female, conf = 0.998
# Age Output : [[5.0933348e-05 5.0010858e-04 3.5204008e-01 4.8127086e-04 6.4503402e-01
#   1.2850746e-03 5.1821303e-04 9.0321497e-05]]
# Age : (25-32), conf = 0.645
# Gender : Female, conf = 0.997
# Age Output : [[1.6125185e-05 3.4814730e-05 3.5219301e-02 1.6071167e-04 9.6293187e-01
#   1.0980893e-03 5.0186849e-04 3.7239046e-05]]
# Age : (25-32), conf = 0.963
# Gender : Female, conf = 0.999
# Age Output : [[7.9950978e-06 8.5377142e-06 3.3984218e-02 1.9289892e-04 9.6225089e-01
#   2.5150466e-03 9.7033696e-04 7.0075264e-05]]
# Age : (25-32), conf = 0.962
# Gender : Female, conf = 0.997
# Age Output : [[6.5981721e-06 4.3437838e-05 3.9740902e-01 2.9205965e-04 6.0038543e-01
#   1.1254112e-03 6.8241585e-04 5.5639845e-05]]
# Age : (25-32), conf = 0.600
# Gender : Female, conf = 0.526
# Age Output : [[0.00119896 0.06840606 0.814645   0.0400744  0.03761636 0.03275348
#   0.00361572 0.00169006]]
# Age : (8-12), conf = 0.815
# Gender : Female, conf = 0.994
# Age Output : [[3.0870369e-06 4.7091358e-05 8.4953737e-01 2.0558566e-04 1.4927855e-01
#   6.5208803e-04 2.4485591e-04 3.1361767e-05]]
# Age : (8-12), conf = 0.850
# Gender : Female, conf = 0.790
# Age Output : [[0.00178067 0.10511666 0.74722916 0.0389185  0.0530405  0.043566
#   0.00804157 0.00230699]]
# Age : (8-12), conf = 0.747
# Gender : Female, conf = 0.995
# Age Output : [[2.3887828e-06 1.3444113e-05 5.4527187e-01 3.0306532e-04 4.5019737e-01
#   3.7505948e-03 3.8494082e-04 7.6296768e-05]]
# Age : (8-12), conf = 0.545
# Gender : Female, conf = 0.635
# Age Output : [[0.00213864 0.18704286 0.67239785 0.03162151 0.07706296 0.02319925
#   0.00481644 0.0017206 ]]
# Age : (8-12), conf = 0.672
# Gender : Female, conf = 0.992
# Age Output : [[2.8143099e-06 4.7275016e-06 2.5418776e-01 3.8023535e-04 7.3293155e-01
#   1.1354526e-02 9.5219963e-04 1.8615999e-04]]
# Age : (25-32), conf = 0.733
# Gender : Female, conf = 0.650
# Age Output : [[0.01862421 0.556994   0.25082353 0.05933634 0.03792614 0.04857317
#   0.02237524 0.0053473 ]]
# Age : (4-6), conf = 0.557
# Gender : Female, conf = 0.995
# Age Output : [[4.7954532e-06 4.2498045e-06 2.1115139e-01 6.5109675e-04 7.6713747e-01
#   1.8857168e-02 1.8358330e-03 3.5805686e-04]]
# Age : (25-32), conf = 0.767
# Gender : Male, conf = 0.778
# Age Output : [[0.02086783 0.22364701 0.10325284 0.12789421 0.04967854 0.3035279
#   0.14541116 0.02572047]]
# Age : (38-43), conf = 0.304
# Gender : Female, conf = 0.999
# Age Output : [[4.0790037e-06 2.9377932e-06 8.5525557e-02 4.8895372e-04 8.8502532e-01
#   2.6259419e-02 2.3044467e-03 3.8927872e-04]]
# Age : (25-32), conf = 0.885
# Gender : Male, conf = 0.988
# Age Output : [[0.00946254 0.07144044 0.03709809 0.06085541 0.25019112 0.2532369
#   0.29575825 0.0219573 ]]
# Age : (48-53), conf = 0.296
# Gender : Female, conf = 0.998
# Age Output : [[4.7235030e-06 3.6993365e-06 1.1030209e-01 4.3470375e-04 8.6089933e-01
#   2.4947353e-02 2.8888071e-03 5.1930646e-04]]
# Age : (25-32), conf = 0.861
# Gender : Male, conf = 0.988
# Age Output : [[0.00123734 0.02009766 0.10158605 0.01645852 0.77844846 0.03078744
#   0.04893915 0.0024454 ]]
# Age : (25-32), conf = 0.778
# Gender : Female, conf = 0.999
# Age Output : [[7.4979057e-06 5.4700231e-06 2.7507377e-01 6.0670014e-04 6.8569630e-01
#   3.4512050e-02 3.2862136e-03 8.1199198e-04]]
# Age : (25-32), conf = 0.686
# Gender : Female, conf = 0.998
# Age Output : [[1.06084235e-05 4.04588718e-06 1.81399852e-01 9.23852145e-04
#   7.61980176e-01 5.24971671e-02 2.32303422e-03 8.61301436e-04]]
# Age : (25-32), conf = 0.762
# Gender : Female, conf = 0.998
# Age Output : [[1.2731622e-05 3.0825929e-06 1.6684029e-01 7.6710357e-04 7.7898628e-01
#   5.0212942e-02 2.1734620e-03 1.0041245e-03]]
# Age : (25-32), conf = 0.779
# Gender : Female, conf = 0.998
# Age Output : [[1.2233945e-05 1.9647805e-06 1.0687672e-01 8.9988741e-04 7.9888958e-01
#   9.0630427e-02 1.6901523e-03 9.9903997e-04]]
# Age : (25-32), conf = 0.799
# Gender : Female, conf = 0.999
# Age Output : [[1.1274119e-05 1.5118754e-06 9.0077065e-02 8.0543780e-04 8.0313188e-01
#   1.0362326e-01 1.5511044e-03 7.9840451e-04]]
# Age : (25-32), conf = 0.803
# Gender : Female, conf = 0.998
# Age Output : [[4.3409068e-06 1.0488538e-06 8.4627673e-02 5.3348625e-04 8.5773414e-01
#   5.5695117e-02 9.4100070e-04 4.6316494e-04]]
# Age : (25-32), conf = 0.858
# Gender : Female, conf = 0.998
# Age Output : [[3.6432943e-06 8.6273013e-07 1.4507064e-01 7.7492534e-04 7.8041440e-01
#   7.2495267e-02 7.7356136e-04 4.6662072e-04]]
# Age : (25-32), conf = 0.780
# Gender : Female, conf = 0.999
# Age Output : [[3.4397772e-06 7.5106522e-07 7.3415712e-02 8.4018614e-04 8.2659388e-01
#   9.8100469e-02 5.6639698e-04 4.7918243e-04]]
# Age : (25-32), conf = 0.827
# Gender : Female, conf = 0.998
# Age Output : [[3.2525595e-06 9.6731640e-07 1.2869051e-01 8.3300809e-04 7.8525048e-01
#   8.3979681e-02 6.6671357e-04 5.7540205e-04]]
# Age : (25-32), conf = 0.785
# Gender : Female, conf = 0.996
# Age Output : [[5.05638991e-06 9.40227039e-07 1.38030246e-01 1.31398090e-03
#   7.49503255e-01 1.10162206e-01 4.81487601e-04 5.02821116e-04]]
# Age : (25-32), conf = 0.750
# Gender : Female, conf = 0.995
# Age Output : [[1.1094759e-05 1.6022493e-06 1.4993003e-01 1.4393934e-03 7.2697157e-01
#   1.2006283e-01 8.3789439e-04 7.4547197e-04]]
# Age : (25-32), conf = 0.727
# Gender : Female, conf = 0.982
# Age Output : [[1.0489935e-05 1.2913458e-06 1.1932356e-01 2.2429023e-03 7.2378719e-01
#   1.5350409e-01 6.3220336e-04 4.9829239e-04]]
# Age : (25-32), conf = 0.724
# Gender : Female, conf = 0.961
# Age Output : [[2.0867516e-05 2.5777156e-06 2.4253914e-01 2.8230890e-03 6.1927128e-01
#   1.3405830e-01 6.3144264e-04 6.5330794e-04]]
# Age : (25-32), conf = 0.619
# Gender : Female, conf = 0.984
# Age Output : [[1.5979729e-05 5.2200744e-06 5.1989639e-01 4.5007188e-03 4.1779485e-01
#   5.7152718e-02 3.4014939e-04 2.9399016e-04]]
# Age : (8-12), conf = 0.520
# Gender : Female, conf = 0.996
# Age Output : [[1.5825388e-05 4.6943569e-06 7.1591347e-01 4.5966678e-03 2.3444076e-01
#   4.4410225e-02 3.8220204e-04 2.3624595e-04]]
# Age : (8-12), conf = 0.716
# Gender : Female, conf = 0.997
# Age Output : [[3.7317608e-05 6.5635036e-06 6.2358600e-01 6.2369844e-03 2.9147699e-01
#   7.7780955e-02 5.6170952e-04 3.1348315e-04]]
# Age : (8-12), conf = 0.624
# Gender : Female, conf = 0.999
# Age Output : [[4.6199872e-05 6.7934857e-06 7.5755745e-01 5.0004288e-03 1.6954423e-01
#   6.7087926e-02 4.3477761e-04 3.2224273e-04]]
# Age : (8-12), conf = 0.758
# Gender : Female, conf = 0.998
# Age Output : [[3.6640347e-05 7.5677958e-06 7.1323806e-01 5.4647787e-03 2.3270053e-01
#   4.7959439e-02 3.5342807e-04 2.3959884e-04]]
# Age : (8-12), conf = 0.713
# Gender : Female, conf = 0.998
# Age Output : [[2.5385007e-05 6.2979952e-06 6.9935399e-01 6.6641686e-03 2.4711406e-01
#   4.6372302e-02 2.7853600e-04 1.8527337e-04]]
# Age : (8-12), conf = 0.699
# Gender : Female, conf = 0.998
# Age Output : [[5.5511031e-05 8.5165784e-06 4.8390242e-01 1.0398868e-02 4.2011005e-01
#   8.4590621e-02 5.5575464e-04 3.7828152e-04]]
# Age : (8-12), conf = 0.484
# Gender : Female, conf = 0.998
# Age Output : [[2.4628011e-05 6.2426107e-06 3.8148457e-01 1.0725737e-02 5.5134290e-01
#   5.5797499e-02 3.9456974e-04 2.2391525e-04]]
# Age : (25-32), conf = 0.551
# Gender : Female, conf = 0.996
# Age Output : [[2.7771819e-06 5.9839535e-06 6.6604805e-01 4.5803352e-03 3.2032013e-01
#   8.8627851e-03 1.0336125e-04 7.6656099e-05]]
# Age : (8-12), conf = 0.666
# Gender : Female, conf = 0.990
# Age Output : [[3.4362943e-06 8.4080984e-06 6.6176206e-01 7.5729941e-03 3.2207263e-01
#   8.4037278e-03 9.6286298e-05 8.0424572e-05]]
# Age : (8-12), conf = 0.662
# Gender : Female, conf = 0.971
# Age Output : [[5.2157666e-06 1.5526566e-05 4.6714392e-01 1.3760213e-02 5.1330394e-01
#   5.6250701e-03 8.1125196e-05 6.5004882e-05]]
# Age : (25-32), conf = 0.513
# Gender : Female, conf = 0.961
# Age Output : [[3.7378397e-06 1.7312179e-05 7.3995113e-01 1.1627467e-02 2.4355759e-01
#   4.7070333e-03 7.1966497e-05 6.3789375e-05]]
# Age : (8-12), conf = 0.740
# Gender : Female, conf = 0.901
# Age Output : [[3.2137125e-06 2.5313702e-05 7.0838499e-01 1.8339612e-02 2.7126569e-01
#   1.8783404e-03 6.4020758e-05 3.8837323e-05]]
# Age : (8-12), conf = 0.708
# Gender : Female, conf = 0.928
# Age Output : [[1.9525546e-06 2.8203398e-05 9.1313869e-01 8.0961837e-03 7.7983201e-02
#   6.9998711e-04 2.7134485e-05 2.4750427e-05]]
# Age : (8-12), conf = 0.913
# Gender : Female, conf = 0.894
# Age Output : [[1.0065335e-05 6.3742518e-05 9.1806382e-01 1.0303681e-02 7.0904009e-02
#   5.8951206e-04 3.0613879e-05 3.4433735e-05]]
# Age : (8-12), conf = 0.918
# Gender : Female, conf = 0.906
# Age Output : [[1.0012779e-05 5.8496349e-05 9.2774457e-01 9.6712988e-03 6.1849076e-02
#   5.9677317e-04 3.7046924e-05 3.2824111e-05]]
# Age : (8-12), conf = 0.928
# Gender : Female, conf = 0.863
# Age Output : [[1.0636125e-05 8.1951301e-05 8.7664610e-01 1.4118367e-02 1.0829253e-01
#   7.7489245e-04 4.3605622e-05 3.2003587e-05]]
# Age : (8-12), conf = 0.877
# Gender : Female, conf = 0.891
# Age Output : [[1.1784927e-05 1.0798899e-04 9.3350297e-01 9.7229620e-03 5.6198541e-02
#   3.9848263e-04 3.3392131e-05 2.3941071e-05]]
# Age : (8-12), conf = 0.934
# Gender : Female, conf = 0.753
# Age Output : [[1.8560797e-05 1.5463881e-04 9.5010734e-01 6.3041500e-03 4.2988390e-02
#   3.6767143e-04 3.4011344e-05 2.5325160e-05]]
# Age : (8-12), conf = 0.950
# Gender : Female, conf = 0.813
# Age Output : [[8.9274508e-06 9.7279466e-05 9.6873951e-01 5.2860267e-03 2.5554633e-02
#   2.6916640e-04 2.4814597e-05 1.9620617e-05]]
# Age : (8-12), conf = 0.969
# Gender : Female, conf = 0.671
# Age Output : [[2.9290833e-05 2.3216887e-04 9.3075931e-01 1.1817923e-02 5.6427222e-02
#   6.3385413e-04 5.7316345e-05 4.2875421e-05]]
# Age : (8-12), conf = 0.931
# Gender : Female, conf = 0.790
# Age Output : [[1.9041878e-05 2.0471898e-04 9.7552425e-01 7.5987238e-03 1.6276196e-02
#   3.2372080e-04 2.7421405e-05 2.5879905e-05]]
# Age : (8-12), conf = 0.976
# Gender : Female, conf = 0.646
# Age Output : [[3.4411085e-05 5.4719322e-04 9.7444397e-01 7.7678682e-03 1.6880523e-02
#   2.6886235e-04 3.1177497e-05 2.5950925e-05]]
# Age : (8-12), conf = 0.974
# Gender : Female, conf = 0.720
# Age Output : [[4.6343004e-05 8.7346206e-04 9.7286361e-01 1.0783509e-02 1.5125227e-02
#   2.4955301e-04 3.3977991e-05 2.4215940e-05]]
# Age : (8-12), conf = 0.973
# Gender : Female, conf = 0.811
# Age Output : [[2.59082939e-04 2.86048767e-03 9.44358051e-01 1.76787023e-02
#   3.37805413e-02 8.07275763e-04 1.45546306e-04 1.10170215e-04]]
# Age : (8-12), conf = 0.944
# Gender : Female, conf = 0.909
# Age Output : [[3.9006615e-04 2.7007076e-03 9.4926947e-01 1.4446351e-02 3.1697486e-02
#   1.0996913e-03 2.1665115e-04 1.7951224e-04]]
# Age : (8-12), conf = 0.949
# Gender : Female, conf = 0.917
# Age Output : [[1.1217360e-03 4.3137693e-03 9.1510367e-01 1.8574614e-02 5.7425424e-02
#   2.5023192e-03 4.9842853e-04 4.6012359e-04]]
# Age : (8-12), conf = 0.915
# Gender : Female, conf = 0.851
# Age Output : [[4.9102848e-04 4.8001246e-03 9.5935678e-01 1.0538060e-02 2.4033064e-02
#   5.7344913e-04 1.2617775e-04 8.1318060e-05]]
# Age : (8-12), conf = 0.959
# Gender : Female, conf = 0.822
# Age Output : [[1.32063229e-03 9.59225930e-03 9.26633358e-01 1.36886425e-02
#   4.73677069e-02 1.07871997e-03 1.91812695e-04 1.26979270e-04]]
# Age : (8-12), conf = 0.927
# Done processing video
